# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\shrey\OneDrive\Desktop\patient.csv")
print(df1)
# Out:
#     patient_id          name   age  gender     city admission_date height_cm
# 0         P001           NaN  25.0       F   mumbai     15-01-2024       180
# 1         P002  Rahul Sharma  60.0       F    Delhi     16-01-2024       170
# 2         P003    Neha Singh  45.0       M   Mumbai     16-01-2024       150
# 3         P004    Neha Singh  60.0    Male  kolkata     15-01-2024       170
# 4         P005    Neha Singh  25.0    Male  kolkata     15-01-2024       180
# ..         ...           ...   ...     ...      ...            ...       ...
# 125       P006   Anita Verma  25.0       M   Mumbai     15-01-2024       150
# 126       P007    Neha Singh  25.0       F  kolkata     15-01-2024       150
# 127       P008     John Paul  60.0       F  Chennai     15-01-2024       160
# 128       P009           NaN  45.0       M   Mumbai     15-01-2024       150
# 129       P010  Rahul Sharma  60.0  Female  Chennai     16-01-2024       150
#
# [130 rows x 7 columns]

# %%
print(df1.head(5))
# Out:
#   patient_id          name   age gender     city admission_date height_cm
# 0       P001           NaN  25.0      F   mumbai     15-01-2024       180
# 1       P002  Rahul Sharma  60.0      F    Delhi     16-01-2024       170
# 2       P003    Neha Singh  45.0      M   Mumbai     16-01-2024       150
# 3       P004    Neha Singh  60.0   Male  kolkata     15-01-2024       170
# 4       P005    Neha Singh  25.0   Male  kolkata     15-01-2024       180

# %%
print(df1.tail(5))
# Out:
#     patient_id          name   age  gender     city admission_date height_cm
# 125       P006   Anita Verma  25.0       M   Mumbai     15-01-2024       150
# 126       P007    Neha Singh  25.0       F  kolkata     15-01-2024       150
# 127       P008     John Paul  60.0       F  Chennai     15-01-2024       160
# 128       P009           NaN  45.0       M   Mumbai     15-01-2024       150
# 129       P010  Rahul Sharma  60.0  Female  Chennai     16-01-2024       150

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      130 non-null    object
#  1   name            107 non-null    object
#  2   age             106 non-null    float64
#  3   gender          130 non-null    object
#  4   city            130 non-null    object
#  5   admission_date  130 non-null    object
#  6   height_cm       130 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 7.2+ KB
# None

# %%
print(df1.describe())
# Out:
#               age
# count  106.000000
# mean    35.849057
# std     21.015546
# min     -5.000000
# 25%     25.000000
# 50%     30.000000
# 75%     60.000000
# max     60.000000

# %%
print(df1.isna())
# Out:
#      patient_id   name    age  gender   city  admission_date  height_cm
# 0         False   True  False   False  False           False      False
# 1         False  False  False   False  False           False      False
# 2         False  False  False   False  False           False      False
# 3         False  False  False   False  False           False      False
# 4         False  False  False   False  False           False      False
# ..          ...    ...    ...     ...    ...             ...        ...
# 125       False  False  False   False  False           False      False
# 126       False  False  False   False  False           False      False
# 127       False  False  False   False  False           False      False
# 128       False   True  False   False  False           False      False
# 129       False  False  False   False  False           False      False
#
# [130 rows x 7 columns]

# %%
print(df1.isna().sum())
# Out:
# patient_id         0
# name              23
# age               24
# gender             0
# city               0
# admission_date     0
# height_cm          0
# dtype: int64

# %%
print(df1.isna().sum().sum())
# Out:
# 47

# %%
print(df1.ndim)
# Out:
# 2

# %%
print(df1.size)
# Out:
# 910

# %%
print(df1.shape)
# Out:
# (130, 7)

# %%
df1["name"].fillna("x",inplace=True)
print(df1)
# Out:
#     patient_id          name   age  gender     city admission_date height_cm
# 0         P001             x  25.0       F   mumbai     15-01-2024       180
# 1         P002  Rahul Sharma  60.0       F    Delhi     16-01-2024       170
# 2         P003    Neha Singh  45.0       M   Mumbai     16-01-2024       150
# 3         P004    Neha Singh  60.0    Male  kolkata     15-01-2024       170
# 4         P005    Neha Singh  25.0    Male  kolkata     15-01-2024       180
# ..         ...           ...   ...     ...      ...            ...       ...
# 125       P006   Anita Verma  25.0       M   Mumbai     15-01-2024       150
# 126       P007    Neha Singh  25.0       F  kolkata     15-01-2024       150
# 127       P008     John Paul  60.0       F  Chennai     15-01-2024       160
# 128       P009             x  45.0       M   Mumbai     15-01-2024       150
# 129       P010  Rahul Sharma  60.0  Female  Chennai     16-01-2024       150
#
# [130 rows x 7 columns]
# ...

# %%
print(df1["name"].isna())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# Name: name, Length: 130, dtype: bool

# %%
print(df1["name"].isna().sum())
# Out:
# 0

# %%
print(df1["age"].isna())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# Name: age, Length: 130, dtype: bool

# %%
df1["age"].fillna(df1["age"].mean,inplace=True)
print(df1)
# Out:
#     patient_id          name   age  gender     city admission_date height_cm
# 0         P001             x  25.0       F   mumbai     15-01-2024       180
# 1         P002  Rahul Sharma  60.0       F    Delhi     16-01-2024       170
# 2         P003    Neha Singh  45.0       M   Mumbai     16-01-2024       150
# 3         P004    Neha Singh  60.0    Male  kolkata     15-01-2024       170
# 4         P005    Neha Singh  25.0    Male  kolkata     15-01-2024       180
# ..         ...           ...   ...     ...      ...            ...       ...
# 125       P006   Anita Verma  25.0       M   Mumbai     15-01-2024       150
# 126       P007    Neha Singh  25.0       F  kolkata     15-01-2024       150
# 127       P008     John Paul  60.0       F  Chennai     15-01-2024       160
# 128       P009             x  45.0       M   Mumbai     15-01-2024       150
# 129       P010  Rahul Sharma  60.0  Female  Chennai     16-01-2024       150
#
# [130 rows x 7 columns]

# %%
print(df1["age"].isna())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# Name: age, Length: 130, dtype: bool

# %%
print(df1["age"].isna().sum())
# Out:
# 0

# %%
df1["name"]
# Out:
# 0                 x
# 1      Rahul Sharma
# 2        Neha Singh
# 3        Neha Singh
# 4        Neha Singh
#            ...
# 125     Anita Verma
# 126      Neha Singh
# 127       John Paul
# 128               x
# 129    Rahul Sharma
# Name: name, Length: 130, dtype: object

# %%
df1["admission_date"]
# Out:
# 0      15-01-2024
# 1      16-01-2024
# 2      16-01-2024
# 3      15-01-2024
# 4      15-01-2024
#           ...
# 125    15-01-2024
# 126    15-01-2024
# 127    15-01-2024
# 128    15-01-2024
# 129    16-01-2024
# Name: admission_date, Length: 130, dtype: object

# %%
print(df1.isna().sum())
# Out:
# patient_id        0
# name              0
# age               0
# gender            0
# city              0
# admission_date    0
# height_cm         0
# dtype: int64
